# %% [markdown]
# ## Importing the required libraries

# %%
import json
import tweepy
from tweepy import Cursor
from tqdm import tqdm
import jsonlines
import pandas as pd

# %% [markdown]
# ## Api keys and access tokens

# %%
ACCESS_TOKEN = 'xxx'
ACCESS_SECRET = 'xxx'
CONSUMER_KEY = 'xxx'
CONSUMER_SECRET = 'xxx'

# %% [markdown]
# ## authenticating with Twitter credentials

# %%
auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

# %% [markdown]
# ## api to connect to twitter with my credentials

# %%
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True, compression=True)

# %% [markdown]
# ## testing the API syntax
# #### -cursor is used to iterate through timelines, user lists pages etc
# #### items is set to 1 as we want only 1 tweet to see if it's working

# %%
for status in tweepy.Cursor(api.home_timeline, tweet_mode="extended",entities = "extended").items(1):
    x = status._json
    print(x)
# Out:
# {'created_at': 'Sat Apr 06 15:01:10 +0000 2019', 'id': 1114543577684746240, 'id_str': '1114543577684746240', 'full_text': '60+ #Free #Books on #BigData, #DataScience, #DataMining, #MachineLearning, #Python, R, and more #KDN https://t.co/TRyJTymhTM', 'truncated': False, 'display_text_range': [0, 124], 'entities': {'hashtags': [{'text': 'Free', 'indices': [4, 9]}, {'text': 'Books', 'indices': [10, 16]}, {'text': 'BigData', 'indices': [20, 28]}, {'text': 'DataScience', 'indices': [30, 42]}, {'text': 'DataMining', 'indices': [44, 55]}, {'text': 'MachineLearning', 'indices': [57, 73]}, {'text': 'Python', 'indices': [75, 82]}, {'text': 'KDN', 'indices': [96, 100]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/TRyJTymhTM', 'expanded_url': 'http://ow.ly/ztin30ohGRJ', 'display_url': 'ow.ly/ztin30ohGRJ', 'indices': [101, 124]}]}, 'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 20167623, 'id_str': '20167623', 'name': 'KDnuggets', 'screen_name': 'kdnuggets', 'location': 'Brookline, MA, USA', 'description': 'Covering #AI, #Analytics, #BigData, #DataMining, #DataScience #MachineLearning, #DeepLearning.  Founded by Gregory Piatetsky-Shapiro.', 'url': 'https://t.co/pTYBq6ncsT', 'entities': {'url': {'urls': [{'url': 'https://t.co/pTYBq6ncsT', 'expanded_url': 'https://www.kdnuggets.com/', 'display_url': 'kdnuggets.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 144345, 'friends_count': 413, 'listed_count': 6093, 'created_at': 'Thu Feb 05 17:37:26 +0000 2009', 'favourites_count': 642, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 55661, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '0099B9', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/795788806008041473/0nTPcRja_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/795788806008041473/0nTPcRja_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/20167623/1476546748', 'profile_link_color': '0099B9', 'profile_sidebar_border_color': '5ED4DC', 'profile_sidebar_fill_color': '95E8EC', 'profile_text_color': '3C3940', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'regular'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 2, 'favorite_count': 6, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'possibly_sensitive_appealable': False, 'lang': 'en'}

# %% [markdown]
# # Task
# You have to write a python script which can fetch all the tweets(as many as allowed by Twitter
# API) done by midas@IIITD twitter handle and dump the responses into JSONlines file.
# The other part of your script should be able to parse these JSONline files to display the
# following for every tweet in a tabular format.
#
# ● The text of the tweet.
#
# ● Date and time of the tweet.
#
# ● The number of favorites/likes.
#
# ● The number of retweets.
#
# ● Number of Images present in Tweet. If no image returns None.

# %% [markdown]
# ## Finding the location of required information

# %%
print(x.keys())
print("------")
print(x["user"].keys())
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'full_text', 'truncated', 'display_text_range', 'entities', 'source', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'is_quote_status', 'retweet_count', 'favorite_count', 'favorited', 'retweeted', 'possibly_sensitive', 'possibly_sensitive_appealable', 'lang'])
# ------
# dict_keys(['id', 'id_str', 'name', 'screen_name', 'location', 'description', 'url', 'entities', 'protected', 'followers_count', 'friends_count', 'listed_count', 'created_at', 'favourites_count', 'utc_offset', 'time_zone', 'geo_enabled', 'verified', 'statuses_count', 'lang', 'contributors_enabled', 'is_translator', 'is_translation_enabled', 'profile_background_color', 'profile_background_image_url', 'profile_background_image_url_https', 'profile_background_tile', 'profile_image_url', 'profile_image_url_https', 'profile_banner_url', 'profile_link_color', 'profile_sidebar_border_color', 'profile_sidebar_fill_color', 'profile_text_color', 'profile_use_background_image', 'has_extended_profile', 'default_profile', 'default_profile_image', 'following', 'follow_request_sent', 'notifications', 'translator_type'])

# %% [markdown]
# ### tweet['full_text'] gives text of the tweet
# ### tweet['retweet_count'] gives number of retweets
# ### tweet['favorite_count'] gives number of favorites
# ### tweet['created_at'] gives date and time

# %%
x["entities"].keys()
# Out:
# dict_keys(['hashtags', 'symbols', 'user_mentions', 'urls'])

# %% [markdown]
# ### tweet['extended_entities']['media'] has the id's of images if present
# length of tweet['extended_entities']['media'] will give us number of images

# %% [markdown]
# ## checking the rate limit quota:

# %%
api.rate_limit_status()
# Out:
# {'rate_limit_context': {'access_token': '1017043411449319425-OlvJw1QZjXjMExLzoDv1P1fmUSguQx'},
#  'resources': {'lists': {'/lists/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1554564897},
#    '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1554564897},
#    '/lists/subscribers/show': {'limit': 15,
#     'remaining': 15,
#     'reset': 1554564897},
#    '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1554564897},
#    '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1554564897},
#    '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1554564897},
#    '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1554564897},
#    '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1554564897},
#    '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1554564897},
#    '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1554564897}},
#   'application': {'/application/rate_limit_status': {'limit': 180,
#     'remaining': 179,
#     'reset': 1554564897}},
#   'mutes': {'/mutes/users/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1554564897},
#    '/mutes/users/ids': {'limit': 15, 'remaining': 15, 'reset': 1554564897}},
#   'live_video_stream': {'/live_video_stream/status/:id': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1554564897}},
#   'friendships': {'/friendships/outgoing': {'limit': 15,
#     'remaining': 15,
#     'reset': 1554564897},
#    '/friendships/list': {'limit': 200, 'remaining': 200, 'reset': 1554564897},
#    '/friendships/no_retweets/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1554564897},
#    '/friendships/lookup': {'limit': 15, 'remaining': 15, 'reset': 1554564897},
#    '/friendships/incoming': {'limit': 15,
#     'remaining': 15,
#     'reset': 1554564897},
#    '/friendships/show': {'limit': 180, 'remaining': 180, 'reset': 1554564897}},
#   'guide': {'/guide': {'limit': 180, 'remaining': 180, 'reset': 1554564897}},
#   'auth': {'/auth/csrf_token': {'limit': 15,
#     'remaining': 15,
#     'reset': 1554564897}},
#   'blocks': {'/blocks/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1554564897},
#    '/blocks/ids': {'limit': 15, 'remaining': 15, 'reset': 1554564897}},
#   'geo': {'/geo/similar_places': {'limit': 15,
#     'remaining': 15,
#     'reset': 1554564897},
#    '/geo/id/:place_id': {'limit': 75, 'remaining': 75, 'reset': 1554564897},
#    '/geo/reverse_geocode': {'limit': 15, 'remaining': 15, 'reset': 1554564897},
#    '/geo/search': {'limit': 15, 'remaining': 15, 'reset': 1554564897}},
#   'users': {'/users/report_spam': {'limit': 15,
#     'remaining': 15,
#     'reset': 1554564897},
#    '/users/contributors/pending': {'limit': 2000,
#     'remaining': 2000,
#     'reset': 1554564897},
#    '/users/show/:id': {'limit': 900, 'remaining': 900, 'reset': 1554564897},
#    '/users/search': {'limit': 900, 'remaining': 900, 'reset': 1554564897},
#    '/users/suggestions/:slug': {'limit': 15,
#     'remaining': 15,
#     'reset': 1554564897},
#    '/users/contributees/pending': {'limit': 200,
#     'remaining': 200,
#     'reset': 1554564897},
#    '/users/derived_info': {'limit': 15, 'remaining': 15, 'reset': 1554564897},
#    '/users/profile_banner': {'limit': 180,
#     'remaining': 180,
#     'reset': 1554564897},
#    '/users/suggestions/:slug/members': {'limit': 15,
#     'remaining': 15,
#     'reset': 1554564897},
#    '/users/lookup': {'limit': 900, 'remaining': 900, 'reset': 1554564897},
#    '/users/suggestions': {'limit': 15, 'remaining': 15, 'reset': 1554564897}},
#   'followers': {'/followers/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1554564897},
#    '/followers/list': {'limit': 15, 'remaining': 15, 'reset': 1554564897}},
#   'collections': {'/collections/list': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1554564897},
#    '/collections/entries': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1554564897},
#    '/collections/show': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1554564897}},
#   'statuses': {'/statuses/retweeters/ids': {'limit': 75,
#     'remaining': 75,
#     'reset': 1554564897},
#    '/statuses/retweets_of_me': {'limit': 75,
#     'remaining': 75,
#     'reset': 1554564897},
#    '/statuses/home_timeline': {'limit': 15,
#     'remaining': 14,
#     'reset': 1554564873},
#    '/statuses/show/:id': {'limit': 900, 'remaining': 900, 'reset': 1554564897},
#    '/statuses/user_timeline': {'limit': 900,
#     'remaining': 900,
#     'reset': 1554564897},
#    '/statuses/friends': {'limit': 15, 'remaining': 15, 'reset': 1554564897},
#    '/statuses/retweets/:id': {'limit': 75,
#     'remaining': 75,
#     'reset': 1554564897},
#    '/statuses/mentions_timeline': {'limit': 75,
#     'remaining': 75,
#     'reset': 1554564897},
#    '/statuses/oembed': {'limit': 180, 'remaining': 180, 'reset': 1554564897},
#    '/statuses/lookup': {'limit': 900, 'remaining': 900, 'reset': 1554564897}},
#   'custom_profiles': {'/custom_profiles/list': {'limit': 180,
#     'remaining': 180,
#     'reset': 1554564897},
#    '/custom_profiles/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1554564897}},
#   'webhooks': {'/webhooks/subscriptions/direct_messages': {'limit': 15,
#     'remaining': 15,
#     'reset': 1554564897},
#    '/webhooks': {'limit': 15, 'remaining': 15, 'reset': 1554564897}},
#   'contacts': {'/contacts/uploaded_by': {'limit': 300,
#     'remaining': 300,
#     'reset': 1554564897},
#    '/contacts/users': {'limit': 300, 'remaining': 300, 'reset': 1554564897},
#    '/contacts/addressbook': {'limit': 300,
#     'remaining': 300,
#     'reset': 1554564897},
#    '/contacts/users_and_uploaded_by': {'limit': 300,
#     'remaining': 300,
#     'reset': 1554564897},
#    '/contacts/delete/status': {'limit': 300,
#     'remaining': 300,
#     'reset': 1554564897}},
#   'labs': {'/labs/:version/users': {'limit': 3000,
#     'remaining': 3000,
#     'reset': 1554564897},
#    '/labs/:version/tweets': {'limit': 3000,
#     'remaining': 3000,
#     'reset': 1554564897}},
#   'i': {'/i/config': {'limit': 15, 'remaining': 15, 'reset': 1554564897}},
#   'tweet_prompts': {'/tweet_prompts/report_interaction': {'limit': 180,
#     'remaining': 180,
#     'reset': 1554564897},
#    '/tweet_prompts/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1554564897}},
#   'moments': {'/moments/statuses/update': {'limit': 5,
#     'remaining': 5,
#     'reset': 1554564897},
#    '/moments/permissions': {'limit': 300,
#     'remaining': 300,
#     'reset': 1554564897}},
#   'help': {'/help/tos': {'limit': 15, 'remaining': 15, 'reset': 1554564897},
#    '/help/configuration': {'limit': 15, 'remaining': 15, 'reset': 1554564897},
#    '/help/privacy': {'limit': 15, 'remaining': 15, 'reset': 1554564897},
#    '/help/settings': {'limit': 15, 'remaining': 15, 'reset': 1554564897},
#    '/help/languages': {'limit': 15, 'remaining': 15, 'reset': 1554564897}},
#   'feedback': {'/feedback/show/:id': {'limit': 180,
#     'remaining': 180,
#     'reset': 1554564897},
#    '/feedback/events': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1554564897}},
#   'business_experience': {'/business_experience/dashboard_settings/destroy': {'limit': 450,
#     'remaining': 450,
#     'reset': 1554564897},
#    '/business_experience/dashboard_features': {'limit': 450,
#     'remaining': 450,
#     'reset': 1554564897},
#    '/business_experience/keywords': {'limit': 450,
#     'remaining': 450,
#     'reset': 1554564897},
#    '/business_experience/dashboard_settings/update': {'limit': 450,
#     'remaining': 450,
#     'reset': 1554564897},
#    '/business_experience/dashboard_settings/show': {'limit': 450,
#     'remaining': 450,
#     'reset': 1554564897}},
#   'graphql&POST': {'/graphql&POST': {'limit': 2500,
#     'remaining': 2500,
#     'reset': 1554564897}},
#   'friends': {'/friends/following/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1554564897},
#    '/friends/following/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1554564897},
#    '/friends/list': {'limit': 15, 'remaining': 15, 'reset': 1554564897},
#    '/friends/ids': {'limit': 15, 'remaining': 15, 'reset': 1554564897}},
#   'sandbox': {'/sandbox/account_activity/webhooks/:id/subscriptions': {'limit': 500,
#     'remaining': 500,
#     'reset': 1554564897}},
#   'drafts': {'/drafts/statuses/update': {'limit': 450,
#     'remaining': 450,
#     'reset': 1554564897},
#    '/drafts/statuses/destroy': {'limit': 450,
#     'remaining': 450,
#     'reset': 1554564897},
#    '/drafts/statuses/ids': {'limit': 450,
#     'remaining': 450,
#     'reset': 1554564897},
#    '/drafts/statuses/list': {'limit': 450,
#     'remaining': 450,
#     'reset': 1554564897},
#    '/drafts/statuses/show': {'limit': 450,
#     'remaining': 450,
#     'reset': 1554564897},
#    '/drafts/statuses/create': {'limit': 450,
#     'remaining': 450,
#     'reset': 1554564897}},
#   'direct_messages': {'/direct_messages/sent': {'limit': 300,
#     'remaining': 300,
#     'reset': 1554564897},
#    '/direct_messages/broadcasts/list': {'limit': 60,
#     'remaining': 60,
#     'reset': 1554564897},
#    '/direct_messages/subscribers/lists/members/show': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1554564897},
#    '/direct_messages/mark_read': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1554564897},
#    '/direct_messages/subscribers/ids': {'limit': 180,
#     'remaining': 180,
#     'reset': 1554564897},
#    '/direct_messages/sent_and_received': {'limit': 300,
#     'remaining': 300,
#     'reset': 1554564897},
#    '/direct_messages/broadcasts/statuses/list': {'limit': 60,
#     'remaining': 60,
#     'reset': 1554564897},
#    '/direct_messages': {'limit': 300, 'remaining': 300, 'reset': 1554564897},
#    '/direct_messages/subscribers/lists/members/ids': {'limit': 180,
#     'remaining': 180,
#     'reset': 1554564897},
#    '/direct_messages/subscribers/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1554564897},
#    '/direct_messages/broadcasts/show': {'limit': 60,
#     'remaining': 60,
#     'reset': 1554564897},
#    '/direct_messages/broadcasts/statuses/show': {'limit': 60,
#     'remaining': 60,
#     'reset': 1554564897},
#    '/direct_messages/subscribers/lists/list': {'limit': 180,
#     'remaining': 180,
#     'reset': 1554564897},
#    '/direct_messages/show': {'limit': 300,
#     'remaining': 300,
#     'reset': 1554564897},
#    '/direct_messages/events/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1554564897},
#    '/direct_messages/subscribers/lists/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1554564897},
#    '/direct_messages/events/show': {'limit': 15,
#     'remaining': 15,
#     'reset': 1554564897}},
#   'media': {'/media/upload': {'limit': 500,
#     'remaining': 500,
#     'reset': 1554564897}},
#   'traffic': {'/traffic/map': {'limit': 15,
#     'remaining': 15,
#     'reset': 1554564897}},
#   'account_activity': {'/account_activity/all/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1554564897},
#    '/account_activity/all/:instance_name/subscriptions': {'limit': 500,
#     'remaining': 500,
#     'reset': 1554564897},
#    '/account_activity/direct_messages/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1554564897},
#    '/account_activity/webhooks/:id/subscriptions/direct_messages/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1554564897},
#    '/account_activity/webhooks/:id/subscriptions/all': {'limit': 500,
#     'remaining': 500,
#     'reset': 1554564897},
#    '/account_activity/direct_messages/:instance_name/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1554564897},
#    '/account_activity/webhooks/:id/subscriptions/all/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1554564897},
#    '/account_activity/webhooks/:id/subscriptions/direct_messages': {'limit': 500,
#     'remaining': 500,
#     'reset': 1554564897},
#    '/account_activity/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1554564897},
#    '/account_activity/direct_messages/:instance_name/subscriptions': {'limit': 15,
#     'remaining': 15,
#     'reset': 1554564897},
#    '/account_activity/webhooks/:id/subscriptions': {'limit': 500,
#     'remaining': 500,
#     'reset': 1554564897},
#    '/account_activity/all/:instance_name/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1554564897}},
#   'account': {'/account/login_verification_enrollment': {'limit': 15,
#     'remaining': 15,
#     'reset': 1554564897},
#    '/account/update_profile': {'limit': 15,
#     'remaining': 15,
#     'reset': 1554564897},
#    '/account/verify_credentials': {'limit': 75,
#     'remaining': 75,
#     'reset': 1554564897},
#    '/account/settings': {'limit': 15, 'remaining': 15, 'reset': 1554564897}},
#   'safety': {'/safety/detection_feedback': {'limit': 450000,
#     'remaining': 450000,
#     'reset': 1554564897}},
#   'favorites': {'/favorites/list': {'limit': 75,
#     'remaining': 75,
#     'reset': 1554564897}},
#   'device': {'/device/token': {'limit': 15,
#     'remaining': 15,
#     'reset': 1554564897}},
#   'tweets': {'/tweets/stream/filter/rules': {'limit': 450,
#     'remaining': 450,
#     'reset': 1554564897},
#    '/tweets/stream/filter/:instance_name': {'limit': 50,
#     'remaining': 50,
#     'reset': 1554564897},
#    '/tweets/search/:product/:label': {'limit': 1800,
#     'remaining': 1800,
#     'reset': 1554564897},
#    '/tweets/search/:product/:instance/counts': {'limit': 900,
#     'remaining': 900,
#     'reset': 1554564897},
#    '/tweets/stream/filter/rules/:instance_name/validation&POST': {'limit': 450,
#     'remaining': 450,
#     'reset': 1554564897},
#    '/tweets/stream/filter/rules/:instance_name&POST': {'limit': 450,
#     'remaining': 450,
#     'reset': 1554564897},
#    '/tweets/stream/filter/rules/:instance_name&DELETE': {'limit': 450,
#     'remaining': 450,
#     'reset': 1554564897},
#    '/tweets/stream/filter/rules/:instance_name/:rule_id': {'limit': 450,
#     'remaining': 450,
#     'reset': 1554564897}},
#   'saved_searches': {'/saved_searches/destroy/:id': {'limit': 15,
#     'remaining': 15,
#     'reset': 1554564897},
#    '/saved_searches/show/:id': {'limit': 15,
#     'remaining': 15,
#     'reset': 1554564897},
#    '/saved_searches/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1554564897}},
#   'oauth': {'/oauth/invalidate_token': {'limit': 450,
#     'remaining': 450,
#     'reset': 1554564897}},
#   'search': {'/search/tweets': {'limit': 180,
#     'remaining': 180,
#     'reset': 1554564897}},
#   'trends': {'/trends/closest': {'limit': 75,
#     'remaining': 75,
#     'reset': 1554564897},
#    '/trends/available': {'limit': 75, 'remaining': 75, 'reset': 1554564897},
#    '/trends/place': {'limit': 75, 'remaining': 75, 'reset': 1554564897}},
#   'live_pipeline': {'/live_pipeline/events': {'limit': 180,
#     'remaining': 180,
#     'reset': 1554564897}}}}

# %% [markdown]
# # Part 1: fetching all the tweets(as many as allowed by Twitter API) done by midas@IIITD twitter handle and dump the responses into JSONlines file

# %% [markdown]
# ## getting information about the user:

# %%
item = api.get_user(screen_name='midasIIITD')
print("name: " + item.name)
print("screen_name: " + item.screen_name)
print("description: " + item.description)
print("statuses_count: " + str(item.statuses_count))
print("friends_count: " + str(item.friends_count))
print("followers_count: " + str(item.followers_count))
# Out:
# name: MIDAS IIITD
# screen_name: midasIIITD
# description: MIDAS is a group of researchers at IIIT-Delhi who study, analyze, and build different multimedia systems for society leveraging multimodal information.
# statuses_count: 327
# friends_count: 42
# followers_count: 233

# %% [markdown]
# ## making a dictionary of tweets
# ## - used Cursor to parse through the tweets on the user timeline
# ## - tweet_mode was kept "extended" to get the full length of the tweet and not just first 140 characters
# ## - entities was kept "extended" to get id's of all media files present and not just the first
# ## - used a dictionary as we have to save in the jsonlines format so it would be easier, also search time is faster in dictionaries

# %%
tweets = {}
# text = []
tweet_count = 0
for status in tqdm(Cursor(api.user_timeline, screen_name='midasIIITD',tweet_mode="extended",entities = "extended").items()):
    tweet_count += 1
    tweets[tweet_count] = status._json
#     text.append(status.full_text)

#     if tweet_count==100:
#         break
# Out:
# 327it [00:11, 29.41it/s]

# %% [markdown]
# ## checking the dictionary formed

# %%
tweets[1].keys()
for key,matter in tweets[1].items():
    print(key,matter)
# Out:
# created_at Fri Apr 05 16:08:37 +0000 2019
# id 1114198161562775553
# id_str 1114198161562775553
# full_text We have emailed the task details to all candidates who have applied to @midasIIITD internship through IIITD portal. Kindly check your spam folder if you have not received the email. We will evaluate all solutions received until April 10 midnight and announce results by April 14.
# truncated False
# display_text_range [0, 279]
# entities {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'midasIIITD', 'name': 'MIDAS IIITD', 'id': 1021355762575073281, 'id_str': '1021355762575073281', 'indices': [71, 82]}], 'urls': []}
# source <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>
# in_reply_to_status_id None
# in_reply_to_status_id_str None
# in_reply_to_user_id None
# in_reply_to_user_id_str None
# in_reply_to_screen_name None
# user {'id': 1021355762575073281, 'id_str': '1021355762575073281', 'name': 'MIDAS IIITD', 'screen_name': 'midasIIITD', 'location': 'New Delhi, India', 'description': 'MIDAS is a group of researchers at IIIT-Delhi who study, analyze, and build different multimedia systems for society leveraging multimodal information.', 'url': 'https://t.co/Uwg7oSM6mE', 'entities': {'url': {'urls': [{'url': 'https://t.co/Uwg7oSM6mE', 'expanded_url': 'http://midas.iiitd.edu.in/', 'display_url': 'midas.iiitd.edu.in', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 233, 'friends_count': 42, 'listed_count': 0, 'created_at': 'Mon Jul 23 11:26:04 +0000 2018', 'favourites_count': 140, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 327, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1021356444921212928/WmSTJCUs_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1021356444921212928/WmSTJCUs_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1021355762575073281/1554320878', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}
# geo None
# coordinates None
# place None
# contributors None
# is_quote_status False
# retweet_count 1
# favorite_count 7
# favorited False
# retweeted False
# lang en

# %% [markdown]
# ## here tweets is a dictionary of dictionaries
# ## - saving the tweets dictionary in .jsonl format
# ## each tweet gets saved in a line

# %%
with jsonlines.open('output.jsonl', mode='w') as writer:
    for k in tweets.keys():
        writer.write(tweets[k])
writer.close()

# %% [markdown]
# # Part 2: parse these JSONline files to display the following for every tweet in a tabular format

# %% [markdown]
# ## reading the .jsonl file using jsonlines library

# %%
tweet = []
with jsonlines.open('output.jsonl') as reader:
    for obj in reader:
        tweet.append(obj)
reader.close()

# %%
len(tweet[5])
# Out:
# 26

# %% [markdown]
# ## creating a pandas table

# %%
table = pd.DataFrame(columns = ['Text','Date', 'Time','Favorites','Retweets','No. of Images'])

# %% [markdown]
# ## checking if the logic behind number of images work

# %%
len(tweet[20]['extended_entities']['media'])
# Out:
# 1

# %% [markdown]
# ## checking the format of date-time column

# %%
tweet[1]["created_at"]
# Out:
# 'Fri Apr 05 04:05:11 +0000 2019'

# %% [markdown]
# ## for loop to convert the dictionary into pandas table

# %%
for ix in range(len(tweet)):
#     print(type(i))
    i = tweet[ix]
    no_of_images = 0
    if "extended_entities" in i:
        no_of_images = len(i['extended_entities']['media'])
    date_time = i['created_at'].split()                      #splitting the data-time column
    date = date_time[1]+" "+date_time[2]+" "+ date_time[-1]  #date column
    time = date_time[3]+date_time[4]                         #time column
    table.loc[ix] = [i["full_text"],date,time,i['favorite_count'],i['retweet_count'],no_of_images]   #adding the rows

# %% [markdown]
# ## printing the table

# %%
table
# Out:
#                                                   Text         Date  \
# 0    We have emailed the task details to all candid...  Apr 05 2019
# 1    RT @rfpvjr: Our NAACL paper on polarization in...  Apr 05 2019
# 2    RT @kdnuggets: Effective Transfer Learning For...  Apr 05 2019
# 3    RT @stanfordnlp: What’s new in @Stanford CS224...  Apr 03 2019
# 4    RT @DeepMindAI: Today we're releasing a large-...  Apr 03 2019
# 5    RT @ylecun: Congratulations Jitendra Malik !\n...  Apr 03 2019
# 6    RT @IIITDelhi: Another chance to take admissio...  Apr 03 2019
# 7    Dear @midasIIITD internship candidates who hav...  Apr 02 2019
# 8    Looking forward to your paper submission to @I...  Apr 02 2019
# 9    RT @ngrams: Reproducibility in multimedia rese...  Apr 02 2019
# 10   Online application for https://t.co/DJFDrQsHZP...  Apr 01 2019
# 11   RT @ACMMM19: A final reminder of the Reproduci...  Mar 31 2019
# 12   RT @isarth23: Thanks for the support and help ...  Mar 29 2019
# 13   Since SemEval-2019 will be held June 6-7, 2019...  Mar 29 2019
# 14   +@aggarwal_kartik.\nCongrats! Wish you many mo...  Mar 29 2019
# 15   RT @aggarwal_kartik: Our work (@midasIIITD ) a...  Mar 29 2019
# 16   Congratulations! @midasIIITD team, @isarth23 @...  Mar 29 2019
# 17   @EEMLcommunity @radamihalcea too many deadline...  Mar 29 2019
# 18   RT @stanfordnlp: CS224N Natural Language Proce...  Mar 28 2019
# 19   RT @ylecun: Learn PyTorch by running on Google...  Mar 28 2019
# 20   Dr. Vineeth N Balasubramanian will present a T...  Mar 27 2019
# 21   RT @ylecun: I am extremely honored to be the r...  Mar 27 2019
# 22   Thanks to all shortlisted candidates for submi...  Mar 26 2019
# 23   @IEEEBigMM19 @ACMMM19 and 6 days left for work...  Mar 26 2019
# 24   RT @IEEEBigMM19: Hurry Up!\n6 Days left for Ab...  Mar 26 2019
# 25   Congratulations @midasIIITD students Simra Sha...  Mar 25 2019
# 26   The last date for submitting a solution for th...  Mar 24 2019
# 27   RT @IIITDelhi: @IIITDelhi invites application ...  Mar 24 2019
# 28   One more week is left to submit the workshop p...  Mar 24 2019
# 29   RT @IEEEBigMM19: We are honored to have Dr. Ch...  Mar 24 2019
# ..                                                 ...          ...
# 297  RT @TensorFlow: TensorFlow 1.10.0 has been rel...  Aug 09 2018
# 298  @midasIIITD is looking for motivated IIITD MTe...  Aug 08 2018
# 299  @IIITDelhi @ponguru @RatnRajiv The results of ...  Aug 08 2018
# 300  RT @IIITDelhi: @midasIIITD has secured rank 1 ...  Aug 08 2018
# 301  RT @kdnuggets: Comparison of Top 6 Python NLP ...  Aug 07 2018
# 302  Check more details of the 20th IEEE Internatio...  Aug 07 2018
# 303  MR2AMC@ISM 2018 will be organized by @RatnRaji...  Aug 07 2018
# 304  Our workshop proposal named, "MR2AMC: Multimod...  Aug 07 2018
# 305  @NUSComputing Congratulations Abdelhak and Pro...  Aug 06 2018
# 306  RT @goodfellow_ian: One of the most anticipate...  Aug 06 2018
# 307     @the_dhumketu Great to have you in @midasIIITD  Aug 06 2018
# 308  Congratulation @soujanyaporia for being appoin...  Aug 03 2018
# 309  @IIITDelhi @the_dhumketu Thanks team @midasIII...  Aug 01 2018
# 310  RT @IIITDelhi: Congratulations @midasIIITD int...  Aug 01 2018
# 311  RT @learning_pt: Profile of the 5 Indian under...  Aug 01 2018
# 312  Have a look at the list of accepted papers in ...  Jul 31 2018
# 313  RT @goodfellow_ian: https://t.co/hYiWI7ntyk Te...  Jul 31 2018
# 314  RT @IIITDelhi: Congratulations Dr. @RatnRajiv ...  Jul 30 2018
# 315  RT @ylecun: Jitendra Malik, who directs FAIR-M...  Jul 28 2018
# 316  RT @kdnuggets: .@Bloomberg launches free cours...  Jul 28 2018
# 317  RT @TechAtBloomberg: Missed #PyLondinium18? Wa...  Jul 28 2018
# 318  RT @IIITDelhi: We are delighted to announce th...  Jul 28 2018
# 319  Get ready for the annual technical fest of @II...  Jul 27 2018
# 320  Congratulations Dr. @RatnRajiv and team @midas...  Jul 27 2018
# 321  Congratulations MIDAS @midasIIITD intern Prakh...  Jul 25 2018
# 322    MIDAS@IIITD foundation. https://t.co/LKuzyBHzjm  Jul 24 2018
# 323  It feels great to be the part of @IIITDelhi. h...  Jul 24 2018
# 324  Thank you, @toonzratn for designing the logo o...  Jul 24 2018
# 325  We are on Facebook too. Like our page to get o...  Jul 23 2018
# 326  MIDAS is a group of researchers at IIIT-Delhi ...  Jul 23 2018
#
#               Time Favorites Retweets No. of Images
# 0    16:08:37+0000         7        1             0
# 1    04:05:11+0000         0       16             0
# 2    04:04:43+0000         0       10             1
# 3    18:31:53+0000         0       55             0
# 4    17:04:32+0000         0      841             0
# 5    09:03:40+0000         0       16             0
# 6    07:46:02+0000         0        4             0
# 7    04:20:13+0000         8        1             0
# 8    02:44:54+0000         5        1             0
# 9    02:35:44+0000         0        7             0
# 10   06:53:08+0000         6        1             0
# 11   10:21:24+0000         0       10             0
# 12   19:43:24+0000         0        2             0
# 13   17:16:40+0000         9        1             0
# 14   17:04:30+0000         2        0             0
# 15   17:03:29+0000         0        1             0
# 16   17:02:24+0000         9        1             0
# 17   05:35:22+0000         0        0             0
# 18   16:55:01+0000         0      710             0
# 19   16:54:37+0000         0      157             0
# 20   16:09:09+0000         4        1             1
# 21   11:53:40+0000         0     1544             0
# 22   18:12:27+0000         5        1             0
# 23   05:54:49+0000         2        0             0
# 24   05:50:10+0000         0        3             0
# 25   13:01:57+0000        18        1             2
# 26   18:44:01+0000         8        3             0
# 27   18:26:02+0000         0        4             0
# 28   11:34:27+0000         4        0             0
# 29   06:23:37+0000         0        5             0
# ..             ...       ...      ...           ...
# 297  05:59:57+0000         0      265             0
# 298  11:30:56+0000         2        1             0
# 299  05:53:48+0000         3        1             1
# 300  05:45:58+0000         0        1             0
# 301  07:16:33+0000         0       40             1
# 302  02:05:12+0000         1        1             0
# 303  01:58:49+0000         1        1             0
# 304  01:50:33+0000         1        1             0
# 305  17:48:23+0000         0        0             0
# 306  17:46:59+0000         0      103             1
# 307  06:06:47+0000         0        0             0
# 308  05:56:33+0000         6        1             0
# 309  11:47:15+0000         5        1             1
# 310  11:20:07+0000         0        4             0
# 311  05:06:47+0000         0        4             0
# 312  12:11:52+0000         1        0             0
# 313  02:06:26+0000         0      264             0
# 314  07:30:51+0000         0        2             0
# 315  11:07:11+0000         0       57             0
# 316  06:14:09+0000         0      105             0
# 317  06:13:48+0000         0        7             0
# 318  04:08:21+0000         0        6             0
# 319  06:46:44+0000         3        2             0
# 320  04:07:31+0000         8        2             0
# 321  05:14:35+0000         5        1             0
# 322  10:33:23+0000         2        1             0
# 323  10:12:34+0000         2        1             0
# 324  09:46:26+0000         4        1             1
# 325  16:25:05+0000         3        1             0
# 326  12:53:15+0000         7        4             0
#
# [327 rows x 6 columns]
